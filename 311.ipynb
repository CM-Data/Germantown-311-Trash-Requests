# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
threeoneone= pd.read_csv('public_cases_fc.csv')

# %%
threeoneone.head(30)
# Out:
#                                              the_geom        lon  objectid  \
# 0   0101000020E6100000E4B3869C48CB52C07395B403AAF4... -75.176307       111
# 1   0101000020E61000007D98F71785CD52C0D76474DD67FA... -75.211248        50
# 2   0101000020E610000054988C9D8FCD52C0A118D5F922FA... -75.211891        51
# 3   0101000020E6100000B8FD971098C952C0EEE5C271AE08... -75.149906        55
# 4   0101000020E61000006794366E14C252C0DDD28B56C505... -75.032497        58
# 5   0101000020E610000076DB4B3BB1CA52C0A383601B92F8... -75.167067       137
# 6   0101000020E610000096E3FCEA7DC352C0CDBF86759D05... -75.054560        62
# 7   0101000020E6100000097DFA1928C352C0EF803ED34305... -75.049323        63
# 8   0101000020E610000060F8F33316C352C0FE746EA06105... -75.048230        64
# 9   0101000020E6100000938601E803C352C0DE8022584D05... -75.047113        65
# 10  0101000020E6100000DB15FA6019C252C049F3C7B43603... -75.032799        66
# ...

# %%
gtown = pd.DataFrame
for incident in threeoneone:
    if incident['13']== '19144':
        gtown.append(incident)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-fee60d3aabfa> in <module>
#       1 gtown = pd.DataFrame
#       2 for incident in threeoneone:
# ----> 3     if incident['13']== '19144':
#       4         gtown.append(incident)
#       5
#
# TypeError: string indices must be integers

# %%
gtowninstances= threeoneone.loc[:13]
g= gtowninstances[gtowninstances=='19144']
# Out:
# C:\Users\Owner\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
g.head()
# Out:
#   the_geom  lon  objectid  service_request_id status status_notes  \
# 0      NaN  NaN       NaN                 NaN    NaN          NaN
# 1      NaN  NaN       NaN                 NaN    NaN          NaN
# 2      NaN  NaN       NaN                 NaN    NaN          NaN
# 3      NaN  NaN       NaN                 NaN    NaN          NaN
# 4      NaN  NaN       NaN                 NaN    NaN          NaN
#
#   service_name service_code agency_responsible the_geom_webmercator  \
# 0          NaN          NaN                NaN                  NaN
# 1          NaN          NaN                NaN                  NaN
# 2          NaN          NaN                NaN                  NaN
# 3          NaN          NaN                NaN                  NaN
# 4          NaN          NaN                NaN                  NaN
#
#   requested_datetime updated_datetime expected_datetime address zipcode  \
# 0                NaN              NaN               NaN     NaN     NaN
# ...

# %%
gtown= threeoneone.loc[threeoneone['zipcode'] == '19144']

# %%
gtown.head()
# Out:
#     the_geom  lon  objectid  service_request_id  status       status_notes  \
# 263      NaN  NaN       486             8997665  Closed  Question Answered
# 269      NaN  NaN       392             8997553  Closed  Question Answered
# 309      NaN  NaN       558             8997757  Closed  Question Answered
# 463      NaN  NaN       551             8997851  Closed  Question Answered
# 483      NaN  NaN       627             8997937  Closed  Question Answered
#
#             service_name service_code              agency_responsible  \
# 263  Information Request      SR-IR01        Philly311 Contact Center
# 269  Information Request      SR-IR01        Philly311 Contact Center
# 309  Information Request      SR-IR01  First Judicial District/Courts
# 463  Information Request      SR-IR01                       Philly311
# 483  Information Request      SR-IR01        Philly311 Contact Center
#
#     the_geom_webmercator   requested_datetime     updated_datetime  \
# ...

# %%
gtown.describe()
# Out:
#                lon      objectid  service_request_id          lat
# count  7091.000000  1.475600e+04        1.475600e+04  7091.000000
# mean    -75.171087  2.250765e+06        1.012992e+07    40.033608
# std       0.012336  1.813728e+06        1.040880e+06     0.011468
# min     -75.246227  3.920000e+02        8.853580e+06    39.918960
# 25%     -75.176880  5.518635e+05        9.192940e+06    40.027189
# 50%     -75.170934  2.075150e+06        9.563944e+06    40.034015
# 75%     -75.164952  3.938622e+06        1.093744e+07    40.041434
# max     -74.984977  5.969686e+06        1.248510e+07    40.079860

# %%
gtown.shape
# Out:
# (14756, 18)

# %%
gtown['service_name'].unique()
# Out:
# array(['Information Request', 'Salting',
#        'Rubbish/Recyclable Material Collection', 'Graffiti Removal',
#        'Abandoned Vehicle', 'Zoning Residential', 'Other (Streets)',
#        'Construction Site Task Force', 'Smoke Detector',
#        'Vacant House or Commercial', 'Illegal Dumping',
#        'Maintenance Residential or Commercial', 'Street Light Outage',
#        'Inlet Cleaning', 'Complaint (Streets)',
#        'Sanitation / Dumpster Violation', 'Street Defect',
#        'Parks and Rec Safety and Maintenance', 'Building Dangerous',
#        'Directory Assistance', 'Infestation Residential',
#        'Building Construction', 'Traffic (Other)',
#        'Traffic Signal Emergency', 'Vacant Lot Clean-Up',
#        'Tree Dangerous', 'No Heat (Residential)', 'Dead Animal in Street',
#        'Complaints against Fire or EMS', 'Alley Light Outage',
#        'Boarding Room House', 'Shoveling', 'License Residential',
# ...

# %%
garbage= ['Rubbish/Recyclable Material Collection','Illegal Dumping','Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up']

# %%
gtowngarbage= pd.DataFrame()

# %%
for category in garbage:
    temp = gtown.loc[gtown['service_name'] == category]
    gtowngarbage= pd.concat([gtowngarbage,temp])

# %%
gtowngarbage.shape
# Out:
# (1780, 18)

# %%
gtowngarbage.head()
# Out:
#                                                the_geom        lon  objectid  \
# 668   0101000020E61000009EA5F99DC5CA52C06FD2D96EA704... -75.168312       795
# 1261  0101000020E6100000D39AEE8E6FCA52C00F1AB09A9D04... -75.163059      1710
# 2171  0101000020E6100000A11749164BCA52C044BD43FE5704... -75.160833      3043
# 2426  0101000020E6100000B024F575CBCB52C0FD4643DF4005... -75.184293   3265944
# 2433  0101000020E61000003022BC039DCB52C0EFDBD637AC05... -75.181458   3265945
#
#       service_request_id  status status_notes  \
# 668              9475202  Closed          NaN
# 1261             9260578  Closed          NaN
# 2171            11353514  Closed          NaN
# 2426            11738262  Closed          NaN
# 2433            11738577  Closed          NaN
#
#                                 service_name service_code  agency_responsible  \
# 668   Rubbish/Recyclable Material Collection      SR-ST03  Streets Department
# ...

# %%
gtowngarbage['service_name'].unique()
# Out:
# array(['Rubbish/Recyclable Material Collection', 'Illegal Dumping',
#        'Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up'],
#       dtype=object)

# %%
gtowngarbage['service_name'].value_counts()
# Out:
# Rubbish/Recyclable Material Collection    812
# Illegal Dumping                           510
# Vacant Lot Clean-Up                       325
# Sanitation / Dumpster Violation           133
# Name: service_name, dtype: int64

# %%
gtest=gtowngarbage

# %%
gtest['requested_datetime']=pd.to_datetime(gtest.requested_datetime)

# %%
gtest.sort_values('requested_datetime')
# Out:
#                                                   the_geom        lon  \
# 1689175  0101000020E61000004CD0B2303CCA52C07B6C6856F803... -75.159924
# 1683973  0101000020E6100000CE99405327CA52C0ADF933B4E803... -75.158650
# 654311   0101000020E61000003E068E7830CA52C0E23D28A48C03... -75.159208
# 713200   0101000020E6100000A78B1C3B8BCA52C0C2E181D884FE... -75.164748
# 2462817  0101000020E6100000A65F64FACCCA52C0986E12834003... -75.168761
# 649565   0101000020E6100000D8BC056D0DCB52C05220DC329A03... -75.172694
# 734877   0101000020E610000083E1B77C7FCA52C018E43633DD02... -75.164031
# 1690443  0101000020E6100000100C9C4304CB52C0F55566084F02... -75.172135
# 1690444  0101000020E6100000100C9C4304CB52C0F55566084F02... -75.172135
# 1686060  0101000020E610000025613A08D5CA52C0EA9169E1F005... -75.169252
# 652352   0101000020E6100000E3BD72D6CACA52C034DB70B3D302... -75.168630
# 646800   0101000020E6100000C93DFAB236CB52C0BD33A0FF1A03... -75.175214
# ...

# %%
gtest['counttotal']= gtest.sort_values('requested_datetime').groupby('service_name').cumcount()

# %%
gtest = gtest.sort_values('requested_datetime')

# %%
gtest.set_index('requested_datetime')
# Out:
#                                                               the_geom  \
# requested_datetime
# 2014-12-08 13:12:49  0101000020E61000004CD0B2303CCA52C07B6C6856F803...
# 2014-12-08 13:18:56  0101000020E6100000CE99405327CA52C0ADF933B4E803...
# 2014-12-08 14:33:50  0101000020E61000003E068E7830CA52C0E23D28A48C03...
# 2014-12-08 15:23:39  0101000020E6100000A78B1C3B8BCA52C0C2E181D884FE...
# 2014-12-10 10:21:37  0101000020E6100000A65F64FACCCA52C0986E12834003...
# 2014-12-10 13:05:35  0101000020E6100000D8BC056D0DCB52C05220DC329A03...
# 2014-12-10 14:12:09  0101000020E610000083E1B77C7FCA52C018E43633DD02...
# 2014-12-10 14:31:23  0101000020E6100000100C9C4304CB52C0F55566084F02...
# 2014-12-10 14:49:37  0101000020E6100000100C9C4304CB52C0F55566084F02...
# 2014-12-11 14:26:16  0101000020E610000025613A08D5CA52C0EA9169E1F005...
# 2014-12-15 16:48:13  0101000020E6100000E3BD72D6CACA52C034DB70B3D302...
# 2014-12-16 13:46:21  0101000020E6100000C93DFAB236CB52C0BD33A0FF1A03...
# ...

# %%
a=gtest.loc[gtest['service_name']=='Rubbish/Recyclable Material Collection'].plot(x='requested_datetime',y='counttotal', label='Rubbish/Recyclable Material Collection' )
b=gtest.loc[gtest['service_name']=='Illegal Dumping'].plot(x='requested_datetime',y='counttotal', label='Illegal Dumping')
c=gtest.loc[gtest['service_name']=='Sanitation / Dumpster Violation'].plot(x='requested_datetime',y='counttotal', label='Santitation / Dumpster Violation')
d=gtest.loc[gtest['service_name']=='Vacant Lot Clean-Up'].plot(x='requested_datetime',y='counttotal', label='Vacant Lot Cleanup')

# %%
a=gtest.loc[gtest['service_name']=='Rubbish/Recyclable Material Collection'].plot(x='requested_datetime',y='counttotal', label='Rubbish/Recyclable Material Collection')
b=gtest.loc[gtest['service_name']=='Illegal Dumping'].plot(x='requested_datetime',y='counttotal',ax=a, label='Illegal Dumping')
c=gtest.loc[gtest['service_name']=='Sanitation / Dumpster Violation'].plot(x='requested_datetime',y='counttotal',ax=b, label='Sanitation/Dumpster Violation')
d=gtest.loc[gtest['service_name']=='Vacant Lot Clean-Up'].plot(x='requested_datetime',y='counttotal',ax=c, label='Vacant Lot Clean-Up')
plt.ylabel('Number of Requests')
plt.figure(figsize='3424234x324342')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c3914ec4ca05> in <module>
#       4 d=gtest.loc[gtest['service_name']=='Vacant Lot Clean-Up'].plot(x='requested_datetime',y='counttotal',ax=c, label='Vacant Lot Clean-Up')
#       5 plt.ylabel('Number of Requests')
# ----> 6 plt.figure(figsize='3424234x324342')
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     523                                         frameon=frameon,
#     524                                         FigureClass=FigureClass,
# --> 525                                         **kwargs)
#     526
#     527         if figLabel:
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
# ...

# %%
gtest['counttotalall']= gtest.sort_values('requested_datetime').groupby('zipcode').cumcount()

# %%
gtest

# %%
gtest.loc[2426822]['media_url']
# Out:
# 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_7a1826dff79648fa768b814f75a5f463'

# %%
gtest.plot(x='requested_datetime',y='counttotalall', label='All')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'counttotalall'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-ca699d6fe392> in <module>
# ...

# %%
gtest
# Out:
#                                                   the_geom        lon  \
# 1689175  0101000020E61000004CD0B2303CCA52C07B6C6856F803... -75.159924
# 1683973  0101000020E6100000CE99405327CA52C0ADF933B4E803... -75.158650
# 654311   0101000020E61000003E068E7830CA52C0E23D28A48C03... -75.159208
# 713200   0101000020E6100000A78B1C3B8BCA52C0C2E181D884FE... -75.164748
# 2462817  0101000020E6100000A65F64FACCCA52C0986E12834003... -75.168761
# 649565   0101000020E6100000D8BC056D0DCB52C05220DC329A03... -75.172694
# 734877   0101000020E610000083E1B77C7FCA52C018E43633DD02... -75.164031
# 1690443  0101000020E6100000100C9C4304CB52C0F55566084F02... -75.172135
# 1690444  0101000020E6100000100C9C4304CB52C0F55566084F02... -75.172135
# 1686060  0101000020E610000025613A08D5CA52C0EA9169E1F005... -75.169252
# 652352   0101000020E6100000E3BD72D6CACA52C034DB70B3D302... -75.168630
# 646800   0101000020E6100000C93DFAB236CB52C0BD33A0FF1A03... -75.175214
# ...

# %%
a=gtest.loc[gtest['service_name']=='Rubbish/Recyclable Material Collection'].plot.bar(x='requested_datetime',y='counttotal', label='Rubbish/Recyclable Material Collection')
b=gtest.loc[gtest['service_name']=='Illegal Dumping'].plot.bar(x='requested_datetime',y='counttotal',ax=a, label='Illegal Dumping')
c=gtest.loc[gtest['service_name']=='Sanitation / Dumpster Violation'].plot.bar(x='requested_datetime',y='counttotal',ax=b, label='Sanitation/Dumpster Violation')
d=gtest.loc[gtest['service_name']=='Vacant Lot Clean-Up'].plot.bar(x='requested_datetime',y='counttotal',ax=c, label='Vacant Lot Clean-Up')
plt.ylabel('Number of Requests')
plt.figure(figsize=(50,100))

#if entry date req contains str 201x, add to dataframe
#cumcount entries by all together and then plot all of them together

# %%
list=[]
for index, row in gtest.iterrows():
    row['requested_datetime']=str(row['requested_datetime'])
    if row['requested_datetime'].str.contains('2015'):
        if row['service_name']=='Rubbish/Recyclable Material Collection':
            list.append(index, row['counttotal'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-e3f5990a507d> in <module>
#       2 for index, row in gtest.iterrows():
#       3     row['requested_datetime']=str(row['requested_datetime'])
# ----> 4     if row['requested_datetime'].str.contains('2015'):
#       5         if row['service_name']=='Rubbish/Recyclable Material Collection':
#       6             list.append(index, row['counttotal'])
#
# AttributeError: 'str' object has no attribute 'str'

# %%
list=[]
for item in gtest:
    if item.str.contains('2015')==True:
        if item['service_name']=='Rubbish/Recyclable Material Collection':
            list.append(index, row['counttotal'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-ede34ce4d477> in <module>
#       1 list=[]
#       2 for item in gtest:
# ----> 3     if item.str.contains('2015')==True:
#       4         if item['service_name']=='Rubbish/Recyclable Material Collection':
#       5             list.append(index, row['counttotal'])
#
# AttributeError: 'str' object has no attribute 'str'

# %%
import datetime
gtest=gtest.set_index('requested_datetime')

# %%
fifteendat = gtest.loc['2015-01-01':'2016-01-01']
sixteendat = gtest.loc['2016-01-02':'2017-01-01']
seventeendat = gtest.loc['2017-01-02':'2018-01-01']
eighteendat = gtest.loc['2018-01-02':'2019-01-01']
twomonnine= gtest.loc['2019-01-02':'2019-2-28']

# %%
fifteeny = fifteendat['service_name'].value_counts()
sixteeny = sixteendat['service_name'].value_counts()
seventeeny = seventeendat['service_name'].value_counts()
eighteeny = eighteendat['service_name'].value_counts()
nineteeny= twomonnine['service_name'].value_counts()

# %%
print(fifteeny, sixteeny, seventeeny, eighteeny, nineteeny)
print(fifteeny.values, sixteeny.values, seventeeny.values, eighteeny.values, (nineteeny.values*6))
# Out:
# Rubbish/Recyclable Material Collection    260
# Illegal Dumping                           149
# Vacant Lot Clean-Up                        93
# Sanitation / Dumpster Violation            30
# Name: service_name, dtype: int64 Rubbish/Recyclable Material Collection    212
# Illegal Dumping                           176
# Vacant Lot Clean-Up                        95
# Sanitation / Dumpster Violation            39
# Name: service_name, dtype: int64 Rubbish/Recyclable Material Collection    178
# Illegal Dumping                           102
# Vacant Lot Clean-Up                        81
# Sanitation / Dumpster Violation            39
# Name: service_name, dtype: int64 Rubbish/Recyclable Material Collection    147
# Illegal Dumping                            69
# Vacant Lot Clean-Up                        46
# Sanitation / Dumpster Violation            16
# Name: service_name, dtype: int64 Illegal Dumping                           9
# Rubbish/Recyclable Material Collection    8
# ...

# %%
label=pd.Series(['2015', '2016', '2017', '2109'])
x=pd.Series(np.arange(len(x)))
y=pd.Series([260, 149,  93,  30])

plt.bar(x=x, y=y, height=15)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-0c500a83e6c1> in <module>
#       3 y=pd.Series([260, 149,  93,  30])
#       4
# ----> 5 plt.bar(x=x, y=y, height=15)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
plt.bar([2015, 2016, 2017, 2018,2015, 2016, 2017,2018,2015, 2016, 2017, 2018,2015, 2016, 2017, 2018], [260, 149,  93,  30, 212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16,36, 32, 28, 16] )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-261ac7320eb7> in <module>
# ----> 1 plt.bar([2015, 2016, 2017, 2018,2015, 2016, 2017,2018,2015, 2016, 2017, 2018,2015, 2016, 2017, 2018], [260, 149,  93,  30, 212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16,36, 32, 28, 16] )
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2457     return gca().bar(
#    2458         x, height, width=width, bottom=bottom, align=align,
# -> 2459         **({"data": data} if data is not None else {}), **kwargs)
#    2460
#    2461
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
yvals=[260, 149,  93,  30,212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16]
xvals=[2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018]

# %%
dicto= {'yvals': [260, 149,  93,  30,212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16],
       'xvals': [2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018],
       'dat': ['Rubbish/Recyclable Material Collection', 'Illegal Dumping',
       'Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up','Rubbish/Recyclable Material Collection', 'Illegal Dumping',
       'Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up','Rubbish/Recyclable Material Collection', 'Illegal Dumping',
       'Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up','Rubbish/Recyclable Material Collection', 'Illegal Dumping',
       'Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up']}
yvals=[260, 149,  93,  30,212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16]
xvals=[2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018]
sns.catplot([2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018], [260, 149,  93,  30,212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16],hue= ['Rubbish/Recyclable Material Collection', 'Illegal Dumping',
       'Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up'], kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-effaf68274a4> in <module>
#       9 xvals=[2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018]
#      10 sns.catplot([2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018], [260, 149,  93,  30,212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16],hue= ['Rubbish/Recyclable Material Collection', 'Illegal Dumping',
# ---> 11        'Sanitation / Dumpster Violation', 'Vacant Lot Clean-Up'], kind='bar')
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
# ...

# %%
rodger= pd.Series(data=np.array([260, 149,  93,  30,212, 176,  95,  39,178, 102,  81,  39,147,  69,  46,  16]),index=[2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018,2015,2016,2017,2018])

# %%
sns.catplot(x='index',y='data',data=rodger)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-d82a38bcfcba> in <module>
# ----> 1 sns.catplot(x='index',y='data',data=rodger)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3714     # facets to ensure representation of all data in the final plot
#    3715     p = _CategoricalPlotter()
# -> 3716     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3717     order = p.group_names
#    3718     hue_order = p.hue_names
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
# ...

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = [12, 30, 1, 8, 22]
bars2 = [28, 6, 16, 5, 10]
bars3 = [29, 3, 24, 25, 17]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E'])
 
# Create legend & Show graphic
plt.legend()
plt.show()

# %%
# set width of bar
barWidth = 0.15
 
# set height of bar
bars1 = [260, 212,178, 147]
bars2 = [149 , 176, 102,69]
bars3 = [93, 95,81, 46]
bars4=[30, 39, 39, 16]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
r4 = [x + barWidth for x in r3]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Rubbish/Recyclable Material Collection')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Illegal Dumping')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Sanitation / Dumpster Violation')
plt.bar(r4, bars4, color='#FFA500', width=barWidth, edgecolor='white', label='Vacant Lot Clean-Up')
 
# Add xticks on the middle of the group bars
plt.xlabel('Year', fontweight='bold')
plt.ylabel('Number of Requests', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['2015', '2016', '2017', '2018'])
plt.title("311 Requests in 19144 (Germantown)") 
plt.grid(linestyle='--', axis='y')
# Create legend & Show graphic
plt.legend(loc=0, fontsize=9)
plt.show()

print(260+149+93+30)
print(147+69+46+16)

278/532
# Out:
# 532
# 278
# 0.5225563909774437

# %%
threeoneone['service_name']==''
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 2502312    False
# 2502313    False
# 2502314    False
# 2502315    False
# 2502316    False
# 2502317    False
# 2502318    False
# 2502319    False
# 2502320    False
# 2502321    False
# 2502322    False
# 2502323    False
# 2502324    False
# 2502325    False
# 2502326    False
# 2502327    False
# 2502328    False
# 2502329    False
# 2502330    False
# 2502331    False
# 2502332    False
# ...

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get(url)
img = Image.open(BytesIO(response.content))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-38755409e66b> in <module>
#       1 from PIL import Image
# ----> 2 import requests
#       3 from io import BytesIO
#       4
#       5 response = requests.get(url)
#
# ModuleNotFoundError: No module named 'requests'

# %%
import urllib2
import io

file = io.StringIO(urllib2.urlopen(URL).read())
img = Image.open(file)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-00f38e6f5a04> in <module>
# ----> 1 import urllib2
#       2 import io
#       3
#       4 file = io.StringIO(urllib2.urlopen(URL).read())
#       5 img = Image.open(file)
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
gtest.head()
# Out:
#                                                   the_geom        lon  \
# 1689175  0101000020E61000004CD0B2303CCA52C07B6C6856F803... -75.159924
# 1683973  0101000020E6100000CE99405327CA52C0ADF933B4E803... -75.158650
# 654311   0101000020E61000003E068E7830CA52C0E23D28A48C03... -75.159208
# 713200   0101000020E6100000A78B1C3B8BCA52C0C2E181D884FE... -75.164748
# 2462817  0101000020E6100000A65F64FACCCA52C0986E12834003... -75.168761
#
#          objectid  service_request_id  status status_notes  \
# 1689175   2859589             8854859  Closed          NaN
# 1683973   2859737             8854890    Open          NaN
# 654311     832044             8855164  Closed          NaN
# 713200     928166             8855336    Open          NaN
# 2462817   5813376             8858843  Closed          NaN
#
#                 service_name service_code                  agency_responsible  \
# 1689175  Vacant Lot Clean-Up      SR-CL02  Community Life Improvement Program
# ...

# %%
opengtest= gtest.loc[gtest['status']=='Open']

# %%
opengtest.head(51)
# Out:
#                                                   the_geom        lon  \
# 1683973  0101000020E6100000CE99405327CA52C0ADF933B4E803... -75.158650
# 713200   0101000020E6100000A78B1C3B8BCA52C0C2E181D884FE... -75.164748
# 734877   0101000020E610000083E1B77C7FCA52C018E43633DD02... -75.164031
# 1249296  0101000020E61000004698814E71CA52C025C33B0AA104... -75.163166
# 1598739  0101000020E61000000F4CA8BF22CA52C0A9E473591204... -75.158371
# 1392870  0101000020E61000005CCEBE55CBCA52C08B9A7D58CE04... -75.168661
# 1093689  0101000020E6100000DA92B0CAA0CB52C0364470B7FF03... -75.181689
# 675253   0101000020E6100000DBDCB9AC99CA52C0549A6248AD03... -75.165630
# 701527   0101000020E6100000F29262F49ACA52C09DB15858AA03... -75.165708
# 713696   0101000020E6100000015ACA647ECA52C0070A7A77FD02... -75.163964
# 206491   0101000020E6100000539CDD3918CB52C0BC54CFF6A603... -75.173354
# 707471   0101000020E6100000EAD9A489D4CA52C051AD953B7904... -75.169222
# ...

# %%
opengtest.shape
# Out:
# (51, 19)

# %%
opengtest['service_name'].value_counts()
# Out:
# Vacant Lot Clean-Up                       44
# Illegal Dumping                            3
# Rubbish/Recyclable Material Collection     2
# Sanitation / Dumpster Violation            2
# Name: service_name, dtype: int64

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure

output_file("bars.html")

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ['2015', '2016', '2017']

data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 3, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (fruit, year) for fruit in fruits for year in years ]
counts = sum(zip(data['2015'], data['2016'], data['2017']), ()) # like an hstack
print( x), print( counts)
# Out:
# [('Apples', '2015'), ('Apples', '2016'), ('Apples', '2017'), ('Pears', '2015'), ('Pears', '2016'), ('Pears', '2017'), ('Nectarines', '2015'), ('Nectarines', '2016'), ('Nectarines', '2017'), ('Plums', '2015'), ('Plums', '2016'), ('Plums', '2017'), ('Grapes', '2015'), ('Grapes', '2016'), ('Grapes', '2017'), ('Strawberries', '2015'), ('Strawberries', '2016'), ('Strawberries', '2017')]
# (2, 5, 3, 1, 3, 2, 4, 3, 4, 3, 2, 4, 2, 4, 5, 4, 6, 3)
# (None, None)

# %%
source = ColumnDataSource(data={'x':[('Apples', '2015'), ('Apples', '2016'), ('Apples', '2017'), ('Pears', '2015'), ('Pears', '2016'), ('Pears', '2017'), ('Nectarines', '2015'), ('Nectarines', '2016'), ('Nectarines', '2017'), ('Plums', '2015'), ('Plums', '2016'), ('Plums', '2017'), ('Grapes', '2015'), ('Grapes', '2016'), ('Grapes', '2017'), ('Strawberries', '2015'), ('Strawberries', '2016'), ('Strawberries', '2017')], 'counts': (2, 5, 3, 1, 3, 2, 4, 3, 4, 3, 2, 4, 2, 4, 5, 4, 6, 3)})

p = figure(x_range=FactorRange(*x), plot_height=250, title="Fruit Counts by Year",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source)

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)

# %%
test=dict(x=5, y=0)

# %%
links=[]
for link in gtest.media_url:
    links.append(link)

# %%
justlinks = [x for x in links if str(x) != 'nan']

# %%
gtest.service_notice.value_counts()
# Out:
# 2 Business Days     754
# 5 Business Days     623
# 90 Business Days    325
# None                 28
# 3 Business Days      12
# 2                     4
# Name: service_notice, dtype: int64

# %%
print (justlinks)
# Out:
# ['https://d17aqltn7cihbm.cloudfront.net/uploads/large_0ec63f82c2b78227359923278b603202', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_0efa39b1816d9a5901255abee43af56e', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_26b7cb02c75bdd79ece63e33f3e0ce9a', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_9c41265dcfb3568e0fba5249afe0187f', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_f0726433d71c436e42170a30c2f9125f', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_2f4a365f8824f777aace748247e3bb12', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_0d86fa6303030052611e3fe33327dade', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_266477b94bcd630fe5e546f93fa1af21', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_93c2b205c250da24167a68a2e2b6c158', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_772772ad70fad41ecebae2f31fe297b6', 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_7a1826dff79648fa768b814f75a5f463', 'https://d17aqltn7cihbm.cloud
# ...

# %%
import webbrowser

# %%
for url in justlinks:
    webbrowser.open(url, new=0, autoraise=True)

# %%
litter =pd.read_csv('litter_index_lines.csv')

# %%
litter.head()
# Out:
#    objectid  seg_id  hundred_block_score        l_hundred_block  \
# 0        67  420542             1.333333  2000 SPRING GARDEN ST
# 1        68  420410             1.333333   2000 MOUNT VERNON ST
# 2        69  421797             1.333333          600 N 21ST ST
# 3        70  420415             1.333333           2100 CLAY ST
# 4        71  421798             1.333333          600 N 21ST ST
#
#         r_hundred_block  street_class street_class_name
# 0    0 SPRING GARDEN ST             2    Major Arterial
# 1  2000 MOUNT VERNON ST             5             Local
# 2         600 N 21ST ST             4         Collector
# 3          2100 CLAY ST             5             Local
# 4         600 N 21ST ST             4         Collector

# %%
print(dict)
# Out:
# <class 'dict'>

# %%
del dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-7f1c028050d8> in <module>
# ----> 1 del dict
#
# NameError: name 'dict' is not defined

# %%
dict(x=5)
# Out:
# {'x': 5}
